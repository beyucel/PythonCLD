# %%
from PIL import Image as im
import numpy
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img=mpimg.imread('1Segmented.tiff')
imgplot = plt.imshow(img)

# %%
imarray = numpy.array(image)

# %%
imarray.shape
# Out:
# (986, 1376)
